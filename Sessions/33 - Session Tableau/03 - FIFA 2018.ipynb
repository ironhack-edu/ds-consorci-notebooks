# %% [markdown]
# ![Tableau](https://koreaprofessional.com/wp-content/uploads/2020/10/tableau2.jpg)

# %% [markdown]
# # FIFA 2018

# %% [markdown]
# - EDA
# - Analysis tab
# - Bar plots
# - Dashboarding
# - Filters in dashboarding
# - Stories in Tableau

# %% [markdown]
# ## EDA

# %% [markdown]
# [docs](https://help.tableau.com/current/pro/desktop/en-us/environ_workspace_analytics_pane.htm)

# %% [markdown]
# - We check the data types: everything's fine

# %% [markdown]
# ### Relationship between potential & wages

# %% [markdown]
# - Columns: Overall
# - Rows: Wage, value

# %% [markdown]
# - Change all of them into dimension
# - Drag overall to color (and change it into dimension again)

# %% [markdown]
# #### Analysis tab

# %% [markdown]
# - Mean: constant line, drag to plot
# - Mean with quartiles: drag to plot

# %% [markdown]
# ![Screenshot%202022-08-29%20at%2002.58.43.png](attachment:Screenshot%202022-08-29%20at%2002.58.43.png)

# %% [markdown]
# - You can also include boxplots

# %% [markdown]
# #### Model tab

# %% [markdown]
# - Summary, modelling and custom

# %% [markdown]
# ![Screenshot%202022-08-29%20at%2003.08.25.png](attachment:Screenshot%202022-08-29%20at%2003.08.25.png)
