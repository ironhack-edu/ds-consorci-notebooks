# %% [markdown]
# ![Tableau](https://koreaprofessional.com/wp-content/uploads/2020/10/tableau2.jpg)

# %% [markdown]
# # Intro

# %% [markdown]
# - Tableau prep: ETL software
# - Tableau Desktop: analysis & visualization
#     - Tableau Public
# - Tableau online
# - Tableau server: companies host their data there

# %% [markdown]
# ![Magic quadrant](https://blog.bismart.com/hs-fs/hubfs/Gartner%20magic%20quadrant%202022.png?width=3432&name=Gartner%20magic%20quadrant%202022.png)

# %% [markdown]
# # Setting up
# Installation: [Tableau Public](https://public.tableau.com/en-us/s/download)

# %% [markdown]
# # Importing

# %% [markdown]
# - Importing
#     - csv: on your left, go to Text file and select the .csv

# %% [markdown]
# - Let's import `co2.csv`.

# %% [markdown]
# - Some configuration about the file, in case it was separated by `;` instead of just commas

# %% [markdown]
# - Mind the Locale: English (United States)

# %% [markdown]
# ![Screenshot%202022-08-26%20at%2000.55.10.png](attachment:Screenshot%202022-08-26%20at%2000.55.10.png)

# %% [markdown]
# - You get a sample of 100 rows by default, but you can tune that number:

# %% [markdown]
# ![Screenshot%202022-08-26%20at%2000.23.33.png](attachment:Screenshot%202022-08-26%20at%2000.23.33.png)

# %% [markdown]
# #### Make sure the data types are correct
#
# - Click on the hastagh on the "Año" column and change it to `Date & Time`. The rest should be in `String` and `Number (decimal)`

# %% [markdown]
# # Exploration

# %% [markdown]
# - Adjust the view so you don't miss any info or have to scroll sideways

# %% [markdown]
# ![Screenshot%202022-08-26%20at%2000.27.48.png](attachment:Screenshot%202022-08-26%20at%2000.27.48.png)

# %% [markdown]
# - Get hue by country: Drag `Nombre del país` to the **Marks** box. Then, drag it to colors.

# %% [markdown]
# ![Screenshot%202022-08-26%20at%2000.29.57.png](attachment:Screenshot%202022-08-26%20at%2000.29.57.png)

# %% [markdown]
# - Filter: SUM of C02 > 5 only: drag from the left panel `Nombre del país`. Click on top and then on By field. Then input 5.

# %% [markdown]
# ![Screenshot%202022-08-26%20at%2000.33.06.png](attachment:Screenshot%202022-08-26%20at%2000.33.06.png)

# %% [markdown]
# - Let's filter one country out: On the filter box, click on `Nombre del país` and Show filter. Uncheck Russia box.

# %% [markdown]
# - Let's include co2 per capita: from the Measures menu, drag it into the Rows box in the upper section

# %% [markdown]
# ![Screenshot%202022-08-26%20at%2000.35.54.png](attachment:Screenshot%202022-08-26%20at%2000.35.54.png)

# %% [markdown]
# - Convert the upper one into an area chart: Mark box > dropdown menu > area

# %% [markdown]
# - Drag `Nombre del país` into `Label` in the Marks box

# %% [markdown]
# - Click on Sheet 1, on the upper section, and change the name to `Co2 in kt and Co2in tons`

# %% [markdown]
# ### Publish your visualization

# %% [markdown]
# - On the upper menu, click on save. Log in or sign up in the pop-window

# %% [markdown]
# # Some things:
# - Configuration when importing
# - Change datatypes
# - View
# - Filtering

# %% [markdown]
# [Embedding into github repo?](https://community.tableau.com/s/question/0D54T00000C6LdFSAV/embed)
